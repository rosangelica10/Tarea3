# %%
import pandas as pd

# %%
adidas = pd.read_csv('adidas.csv')

# %%
adidas.shape
# Out:
# (845, 20)

# %%
adidas.columns
# Out:
# Index(['url', 'name', 'sku', 'selling_price', 'original_price', 'currency',
#        'availability', 'color', 'category', 'source', 'source_website',
#        'breadcrumbs', 'description', 'brand', 'images', 'country', 'language',
#        'average_rating', 'reviews_count', 'crawled_at'],
#       dtype='object')

# %%
#Ejercicio 1

# %%
cols_validas = []
cols_many_levels = []
cols_one_level = []

size_df = adidas.shape[0]
umbral = .98

for c_ in adidas.columns:
    
    niveles = adidas.loc[ : , [c_] ].drop_duplicates().shape[0]
    
    if ( niveles / size_df ) >= umbral:
        cols_many_levels.append(c_)
    elif niveles == 1:
        cols_one_level.append(c_)
    else:
       cols_validas.append(c_)

# %%
#Columnas que si cumplen
cols_many_levels
# Out:
# ['url', 'sku', 'images', 'crawled_at']

# %%
adidas.loc[ :  , cols_many_levels ].drop_duplicates()
# Out:
#                                                    url     sku  \
# 0    https://www.adidas.com/us/beach-shorts/FJ5089....  FJ5089
# 1    https://www.adidas.com/us/five-ten-kestrel-lac...  BC0770
# 2    https://www.adidas.com/us/mexico-away-jersey/G...  GC7946
# 3    https://www.adidas.com/us/five-ten-hiangle-pro...  FV4744
# 4    https://www.adidas.com/us/mesh-broken-stripe-p...  GM0239
# ..                                                 ...     ...
# 840  https://www.adidas.com/us/supernova-plus-shoes...  FX2858
# 841  https://www.adidas.com/us/choigo-shoes/H00667....  H00667
# 842  https://www.adidas.com/us/daily-3.0-shoes/GZ77...  GZ7705
# 843  https://www.adidas.com/us/daily-3.0-shoes/GZ77...  GZ7706
# 844  https://www.adidas.com/us/choigo-shoes/FY6503....  FY6503
#
#                                                 images  \
# 0    https://assets.adidas.com/images/w_600,f_auto,...
# 1    https://assets.adidas.com/images/w_600,f_auto,...
# 2    https://assets.adidas.com/images/w_600,f_auto,...
# 3    https://assets.adidas.com/images/w_600,f_auto,...
# 4    https://assets.adidas.com/images/w_600,f_auto,...
# ..                                                 ...
# 840  https://assets.adidas.com/images/w_600,f_auto,...
# 841  https://assets.adidas.com/images/w_600,f_auto,...
# 842  https://assets.adidas.com/images/w_600,f_auto,...
# 843  https://assets.adidas.com/images/w_600,f_auto,...
# 844  https://assets.adidas.com/images/w_600,f_auto,...
#
#                      crawled_at
# 0    2021-10-23 17:50:17.331255
# 1    2021-10-23 17:50:17.423830
# 2    2021-10-23 17:50:17.530834
# 3    2021-10-23 17:50:17.615054
# 4    2021-10-23 17:50:17.702680
# ..                          ...
# 840  2021-10-23 17:52:31.937924
# 841  2021-10-23 17:52:32.014973
# 842  2021-10-23 17:52:32.208426
# 843  2021-10-23 17:52:32.293622
# 844  2021-10-23 17:52:32.398104
#
# [845 rows x 4 columns]

# %%
cols_validas
# Out:
# ['name',
#  'selling_price',
#  'original_price',
#  'availability',
#  'color',
#  'category',
#  'breadcrumbs',
#  'description',
#  'average_rating',
#  'reviews_count']

# %%
#Ejercicio 2

# %%
cols_validas2 = []
cols_many_levels2 = []
cols_more_level = []

size_df = adidas.shape[0]
umbral = .98

for c_ in adidas.columns:
    
    niveles = adidas.loc[ : , [c_] ].drop_duplicates().shape[0]
    
    if ( niveles / size_df ) >= umbral:
        cols_many_levels2.append(c_)
    elif niveles >= 3 & niveles <= 6:
        cols_more_level.append(c_)
    else:
       cols_validas2.append(c_)

# %%
cols_more_level
# Out:
# ['name',
#  'selling_price',
#  'original_price',
#  'currency',
#  'availability',
#  'color',
#  'category',
#  'source',
#  'source_website',
#  'breadcrumbs',
#  'description',
#  'brand',
#  'country',
#  'language',
#  'average_rating',
#  'reviews_count']

# %%
adidas.loc[ :  , cols_more_level ]
# Out:
#                                                 name  selling_price  \
# 0                                       Beach Shorts             40
# 1          Five Ten Kestrel Lace Mountain Bike Shoes            150
# 2                                 Mexico Away Jersey             70
# 3    Five Ten Hiangle Pro Competition Climbing Shoes            160
# 4                      Mesh Broken-Stripe Polo Shirt             65
# ..                                               ...            ...
# 840                                 Supernova+ Shoes             72
# 841                                     Choigo Shoes             70
# 842                                  Daily 3.0 Shoes             35
# 843                                  Daily 3.0 Shoes             40
# 844                                     Choigo Shoes             70
#
#     original_price currency availability  color  category  \
# 0              NaN      USD      InStock  Black  Clothing
# 1              NaN      USD      InStock   Grey     Shoes
# 2              NaN      USD      InStock  White  Clothing
# 3              NaN      USD      InStock  Black     Shoes
# 4              NaN      USD      InStock   Blue  Clothing
# ..             ...      ...          ...    ...       ...
# 840           $120      USD      InStock  White     Shoes
# 841           $100      USD      InStock  White     Shoes
# 842            $50      USD      InStock  Black     Shoes
# 843            $50      USD      InStock   Pink     Shoes
# 844           $100      USD      InStock  Black     Shoes
#
#                    source          source_website     breadcrumbs  \
# 0    adidas United States  https://www.adidas.com  Women/Clothing
# 1    adidas United States  https://www.adidas.com     Women/Shoes
# 2    adidas United States  https://www.adidas.com   Kids/Clothing
# 3    adidas United States  https://www.adidas.com  Five Ten/Shoes
# 4    adidas United States  https://www.adidas.com    Men/Clothing
# ..                    ...                     ...             ...
# 840  adidas United States  https://www.adidas.com     Women/Shoes
# 841  adidas United States  https://www.adidas.com     Women/Shoes
# 842  adidas United States  https://www.adidas.com      Kids/Shoes
# 843  adidas United States  https://www.adidas.com      Kids/Shoes
# 844  adidas United States  https://www.adidas.com     Women/Shoes
#
#                                            description   brand country  \
# 0    Splashing in the surf. Making memories with yo...  adidas     USA
# 1    Lace up and get after it. The Five Ten Kestrel...  adidas     USA
# 2    Clean and crisp, this adidas Mexico Away Jerse...  adidas     USA
# 3    The Hiangle Pro takes on the classic shape of ...  adidas     USA
# 4    Step up to the tee relaxed. This adidas golf p...  adidas     USA
# ..                                                 ...     ...     ...
# 840  Take off. Touch down. Repeat. These adidas run...  adidas     USA
# 841  If you want drama, the bold female track and f...  adidas     USA
# 842  The style is in the details of the Daily 3.0 S...  adidas     USA
# 843  The style is in the details of the Daily 3.0 S...  adidas     USA
# 844  Take your style to bold new heights. Throw in ...  adidas     USA
#
#     language  average_rating  reviews_count
# 0         en             4.5             35
# 1         en             4.8              4
# 2         en             4.9             42
# 3         en             3.7              7
# 4         en             4.7             11
# ..       ...             ...            ...
# 840       en             4.3            151
# 841       en             4.7            135
# 842       en             4.7            190
# 843       en             4.7            190
# 844       en             4.7            135
#
# [845 rows x 16 columns]

# %%
adidas.loc[ :  , "color"].value_counts() / size_df
# Out:
# White         0.262722
# Black         0.221302
# Blue          0.123077
# Grey          0.095858
# Pink          0.073373
# Green         0.069822
# Purple        0.036686
# Red           0.029586
# Multicolor    0.023669
# Yellow        0.020118
# Orange        0.013018
# Burgundy      0.010651
# Beige         0.007101
# Multi         0.004734
# Gold          0.003550
# Turquoise     0.002367
# Silver        0.001183
# Brown         0.001183
# Name: color, dtype: float64
